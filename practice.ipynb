# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df= pd.read_csv("waterquality.csv",encoding='latin1',index_col="LOCATIONS")

# %%
df
# Out:
#                                                     STATION CODE        STATE  \
# LOCATIONS
# GODAVARI AT JAYAKWADI DAM, AURNAGABAD,MAHARASHTRA           1312  MAHARASHTRA
# GODAVARI RIVER NEAR SOMESHWAR TEMPLE.                       2177  MAHARASHTRA
# GODAVARI RIVER AT SAIKHEDA.                                 2182  MAHARASHTRA
# GODAVARI RIVER AT HANUMAN GHAT, NASHIK CITY.                2179  MAHARASHTRA
# GODAVARI RIVER AT NANDUR- MADMESHWAR DAM.                   2183  MAHARASHTRA
# ...                                                          ...          ...
# GAPE- SAGAR LAKE, DUNGARPUR, RAJASTHAN                      2940    RAJASTHAN
# LAKE JAISAMAND, SALUMBER, UDAIPUR, POINT NO. 1,...          2941    RAJASTHAN
# LAKE JAISAMAND, SALUMBER, UDAIPUR, POINT NO. 2,...          2942    RAJASTHAN
# LODHA TALAB, BANSWARA- DUNGARPUR ROAD, BANSWARA...          2943    RAJASTHAN
# JALMAHAL, JAIPUR, RAJASTHAN                                 2944    RAJASTHAN
#
# ...

# %%
df.head()
# Out:
#                                                    STATION CODE        STATE  \
# LOCATIONS
# GODAVARI AT JAYAKWADI DAM, AURNAGABAD,MAHARASHTRA          1312  MAHARASHTRA
# GODAVARI RIVER NEAR SOMESHWAR TEMPLE.                      2177  MAHARASHTRA
# GODAVARI RIVER AT SAIKHEDA.                                2182  MAHARASHTRA
# GODAVARI RIVER AT HANUMAN GHAT, NASHIK CITY.               2179  MAHARASHTRA
# GODAVARI RIVER AT NANDUR- MADMESHWAR DAM.                  2183  MAHARASHTRA
#
#                                                    TEMP   DO   pH  \
# LOCATIONS
# GODAVARI AT JAYAKWADI DAM, AURNAGABAD,MAHARASHTRA  29.2  6.4  8.1
# GODAVARI RIVER NEAR SOMESHWAR TEMPLE.              24.5  6.0  8.0
# GODAVARI RIVER AT SAIKHEDA.                        25.8  5.5  7.8
# GODAVARI RIVER AT HANUMAN GHAT, NASHIK CITY.       24.8  5.5  7.8
# GODAVARI RIVER AT NANDUR- MADMESHWAR DAM.          25.7  5.7  7.9
#
#                                                    CONDUCTIVITY  BOD  \
# ...

# %%
df.isnull().sum()
# Out:
# STATION CODE            0
# STATE                   0
# TEMP                    5
# DO                      2
# pH                      0
# CONDUCTIVITY           30
# BOD                     6
# NITRATE_N_NITRITE_N     2
# FECAL_COLIFORM         82
# TOTAL_COLIFORM         39
# dtype: int64

# %%
df.columns
# Out:
# Index(['STATION CODE', 'STATE', 'TEMP', 'DO', 'pH', 'CONDUCTIVITY', 'BOD',
#        'NITRATE_N_NITRITE_N', 'FECAL_COLIFORM', 'TOTAL_COLIFORM'],
#       dtype='object')

# %%
df.head
# Out:
# <bound method NDFrame.head of                                                     STATION CODE        STATE  \
# LOCATIONS
# GODAVARI AT JAYAKWADI DAM, AURNAGABAD,MAHARASHTRA           1312  MAHARASHTRA
# GODAVARI RIVER NEAR SOMESHWAR TEMPLE.                       2177  MAHARASHTRA
# GODAVARI RIVER AT SAIKHEDA.                                 2182  MAHARASHTRA
# GODAVARI RIVER AT HANUMAN GHAT, NASHIK CITY.                2179  MAHARASHTRA
# GODAVARI RIVER AT NANDUR- MADMESHWAR DAM.                   2183  MAHARASHTRA
# ...                                                          ...          ...
# GAPE- SAGAR LAKE, DUNGARPUR, RAJASTHAN                      2940    RAJASTHAN
# LAKE JAISAMAND, SALUMBER, UDAIPUR, POINT NO. 1,...          2941    RAJASTHAN
# LAKE JAISAMAND, SALUMBER, UDAIPUR, POINT NO. 2,...          2942    RAJASTHAN
# LODHA TALAB, BANSWARA- DUNGARPUR ROAD, BANSWARA...          2943    RAJASTHAN
# ...

# %%
df['STATE'].value_counts().plot.bar(title='Water Quality in Different state')
plt.show()

# %%
df.plot.scatter(x='TEMP',y='pH',s=30,figsize=(12,10),color='cyan')
# Out:
# <AxesSubplot:xlabel='TEMP', ylabel='pH'>

# %%
df['STATE'].value_counts()
# Out:
# MAHARASHTRA         105
# BIHAR                61
# UTTAR PRADESH        49
# KARNATAKA            48
# ANDHRA PRADESH       43
# MADHYA PRADESH       39
# GOA                  36
# RAJASTHAN            33
# ASSAM                22
# GUJARAT              21
# UTTARAKHAND          19
# HIMACHAL PRADESH     16
# WEST BENGAL          13
# PUNJAB               12
# TAMILNADU             7
# CHHATTISGARH          4
# DELHI                 4
# KERALA                2
# Name: STATE, dtype: int64

# %%
df['STATE'].value_counts().head(10).plot.pie(
                             figsize=(8,7),
                             startangle=90,
                             wedgeprops={'width':.5},
                             radius=1,
                             autopct='%.1f%%',
                             pctdistance=.9,
                             
                             textprops={'color':'yellow'}
)
plt.show()

# %%
df['pH'].value_counts().head(10).plot.bar(title="pH Quantity")
plt.show()

# %%
df['STATION CODE'].value_counts()
# Out:
# 1312    1
# 2655    1
# 3182    1
# 3181    1
# 1475    1
#        ..
# 2618    1
# 2617    1
# 2623    1
# 2622    1
# 2944    1
# Name: STATION CODE, Length: 534, dtype: int64

# %%
df['CONDUCTIVITY'].value_counts().head(10).plot.bar(title="Conductivity Quantity in Water")
# Out:
# <AxesSubplot:title={'center':'Conductivity Quantity in Water'}>

# %%
df.head(30).plot.line(x='STATE',y='BOD',figsize=(17,8))

plt.title("BIOLOGICAL OXYGEN DEMAND OF OXYGEN")
plt.xlabel("STATE")
plt.ylabel("BOD")
plt.show()

# %%
df.head(30).plot.line(x='STATE',y='TEMP',figsize=(17,8))

plt.title("Temperature")
plt.xlabel("STATE")
plt.ylabel("Temp")
plt.show()

# %%
df.head(30).plot.line(x='STATE',y='TOTAL_COLIFORM',figsize=(17,8))
plt.title("Temperature")
plt.xlabel("STATE")
plt.ylabel("Total Coliform")
plt.show()

# %%
df['TOTAL_COLIFORM'].head(10).plot.barh(figsize=(10,10))                       
plt.show()

# %%
df['pH'].value_counts().head(10).plot.pie(
                             figsize=(8,7),
                             startangle=90,
                             wedgeprops={'width':.5},
                             radius=1,
                             autopct='%.1f%%',
                             pctdistance=.9,
                             
                             textprops={'color':'yellow'}
)
plt.show()

# %%
df
# Out:
#                                                     STATION CODE        STATE  \
# LOCATIONS
# GODAVARI AT JAYAKWADI DAM, AURNAGABAD,MAHARASHTRA           1312  MAHARASHTRA
# GODAVARI RIVER NEAR SOMESHWAR TEMPLE.                       2177  MAHARASHTRA
# GODAVARI RIVER AT SAIKHEDA.                                 2182  MAHARASHTRA
# GODAVARI RIVER AT HANUMAN GHAT, NASHIK CITY.                2179  MAHARASHTRA
# GODAVARI RIVER AT NANDUR- MADMESHWAR DAM.                   2183  MAHARASHTRA
# ...                                                          ...          ...
# GAPE- SAGAR LAKE, DUNGARPUR, RAJASTHAN                      2940    RAJASTHAN
# LAKE JAISAMAND, SALUMBER, UDAIPUR, POINT NO. 1,...          2941    RAJASTHAN
# LAKE JAISAMAND, SALUMBER, UDAIPUR, POINT NO. 2,...          2942    RAJASTHAN
# LODHA TALAB, BANSWARA- DUNGARPUR ROAD, BANSWARA...          2943    RAJASTHAN
# JALMAHAL, JAIPUR, RAJASTHAN                                 2944    RAJASTHAN
#
# ...

# %%
df['NITRATE_N_NITRITE_N'].head(20).plot.barh(figsize=(10,10),title='Nitrate of Water Of Diffferent location')                       
plt.show()

# %%
df.head(20).plot.bar(x='STATE',y='pH',hatch='/',color=['gray',],edgecolor='black',figsize=(20,10))
plt.show()

# %%
df.head(30).plot.line(x='STATE',y='DO',figsize=(17,8))

plt.title("DISSOLVED OXYGEN")
plt.xlabel("STATE")
plt.ylabel("BOD")
plt.show()

# %%
df['DO'].head(10).plot.barh(figsize=(10,10))                       
plt.show()

# %%
df['pH'].head(10).plot.bar(figsize=(10,10),title='pH') 
plt.title('pH Value')                      
plt.show()

# %%
df['pH'].head(10).plot.bar(figsize=(10,10),title='pH')
plt.title('pH Value')                       
plt.show()
